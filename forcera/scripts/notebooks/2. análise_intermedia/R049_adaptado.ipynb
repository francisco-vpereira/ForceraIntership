# %% [markdown]
# # Bibliotecas

# %%
# Mudar diretório para chamar scripts com funções
import os
os.chdir('/home/francisco/MECAD/2º Ano/Estágio/forcera/scripts/scripts_py')

# Importar funções e flags definidas em flags.py e functions.py
from functions import *
from flags import * 

import psycopg2
from psycopg2 import OperationalError
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from scipy.optimize import curve_fit
import seaborn as sns
from IPython.display import HTML
import webbrowser
from collections import defaultdict
import networkx as nx

plt.rcParams['figure.figsize'] = (7,5)

# %% [markdown]
# # Ligação à base de dados

# %%
conn = psycopg2.connect(
    host = "contratos-base-gov1.cf87yxnqgph8.eu-central-1.rds.amazonaws.com",
    port = 5432,
    #database = "contratosbasegov",
    user = "contratosbasegov",
    password = "8n9nyeTBFUyCcLJShNrZdPUai2KQkue4")

cur = conn.cursor()

# %% [markdown]
# # DataFrame

# %%
# Filtrar contratos : ID's concursos públicos com CPV's começados por 72
cpub = (cpv('72', 'Concurso público'))

# %%
# Dataframe referente ao conjuntos de contratos públicos celebrados no ramo de consultoria IT 
cp = contratos(cpub)

# %%
# A tabela é representada de forma correta : o id do anúncio bate certo com o preço base, contratual e restantes colunas que são relevantes
# Contudo, a ordem dos ID's em cpub é diferente da ordem dos ids na coluna ID da dataframe
# A ordem os id's guardados na variável cpub não bate certo
# Na célula a seguir a esta, é preciso redefini-la
cp = cp.rename(columns={0:'ID', 1:'NrAnuncio', 2:'PrecoBase', 3:'Prazo', 16:'DataPub', 17:'DataCel', 18:'PrecoContratual',20:'Adjudicante', 22:'Adjudicatária' ,23:'EntConcorrentes'})

cp.PrecoBase = cp.PrecoBase.replace('None',0).astype(float)
cp.PrecoContratual = cp.PrecoContratual.replace('None',0).astype(float)

# %% [markdown]
# # R049 : Determinar número de concursos públicos celebrados por uma determinada entidade num determinado período de tempo
#
# - [x] Colunas Adjudicante e Ajudicatária : Separar elementos de cada uma das colunas em 3 colunas ( Entidade | URL | NIF )
# - [x] Contar número de ocorrências para NIF nos dois casos ( adjudicante e adjudicatária )
# - [x] Aplicar passo anterior num intervalo de tempo

# %%
# Separação dos elementos de cada coluna em Entidade-NIF-URL
# O objetivo é contar o número de ocorrências de cada NIF
pattern = r'^(?P<EntidadeAdjudicante>.*?)\s?\((?P<NIF1>[\w\.-]+)\)\((?P<URL1>.*?)\)$'
pattern1 = r'^(?P<EntidadeAdjudicataria>.*?)\s?\((?P<NIF2>[\w\.-]+)\)\((?P<URL2>.*?)\)$'


Df_extracted =  cp['Adjudicante'].str.extract(pattern)
Df_extracted1 = cp['Adjudicatária'].str.extract(pattern1)


# Correr linhas abaixo só uma vez
# Caso contrário está sempre a adicionar à dataframe as mesas colunas
cp = pd.concat([cp, Df_extracted], axis=1)
cp = pd.concat([cp, Df_extracted1], axis=1)

# %%
h(cp.head(5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>ID</th>
#       <th>NrAnuncio</th>
#       <th>PrecoBase</th>
#       <th>Prazo</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>10</th>
#       <th>11</th>
#       <th>12</th>
#       <th>13</th>
#       <th>14</th>
#       <th>15</th>
#       <th>DataPub</th>
#       <th>DataCel</th>
#       <th>PrecoContratual</th>
#       <th>19</th>
#       <th>Adjudicante</th>
#       <th>21</th>
#       <th>Adjudicatária</th>
#       <th>EntConcorrentes</th>
#       <th>24</th>
#       <th>25</th>
#       <th>26</th>
#       <th>27</th>
#       <th>28</th>
#       <th>29</th>
#       <th>30</th>
#       <th>31</th>
#       <th>32</th>
#       <th>33</th>
#       <th>34</th>
#       <th>35</th>
#       <th>36</th>
#       <th>37</th>
#       <th>38</th>
#       <th>39</th>
#       <th>40</th>
#       <th>41</th>
#       <th>42</th>
#       <th>43</th>
#       <th>44</th>
#       <th>45</th>
#       <th>46</th>
#       <th>47</th>
#       <th>48</th>
#       <th>49</th>
#       <th>50</th>
#       <th>51</th>
#       <th>52</th>
#       <th>53</th>
#       <th>54</th>
#       <th>55</th>
#       <th>56</th>
#       <th>57</th>
#       <th>58</th>
#       <th>59</th>
#       <th>60</th>
#       <th>EntidadeAdjudicante</th>
#       <th>NIF1</th>
#       <th>URL1</th>
#       <th>EntidadeAdjudicataria</th>
#       <th>NIF2</th>
#       <th>URL2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10323405</td>
#       <td>15555/2023</td>
#       <td>137670.00</td>
#       <td>6</td>
#       <td>False</td>
#       <td>6699898</td>
#       <td>13437191</td>
#       <td>2023-09-19</td>
#       <td>182</td>
#       <td>2</td>
#       <td>False</td>
#       <td>False</td>
#       <td>https://dre.pt/application/file/221829278</td>
#       <td>Anúncio de procedimento</td>
#       <td>Concurso público</td>
#       <td>Contratualização de uma Plataforma Educacional de Aprendizagem Digital</td>
#       <td>2023-11-02</td>
#       <td>2023-10-31</td>
#       <td>113524.80</td>
#       <td>332</td>
#       <td>Município de Santarém (505941350)(https://www.base.gov.pt/Base4/pt/detalhe/?type=entidades&amp;id=1785)</td>
#       <td>Artigo 20.º, n.º 1, alínea b) do Código dos Contratos Públicos</td>
#       <td>Porto Editora, S.A. (500221103)(https://www.base.gov.pt/Base4/pt/detalhe/?type=entidades&amp;id=585)</td>
#       <td>None</td>
#       <td>https://www.base.gov.pt/Base4/pt/detalhe/?type=anuncios&amp;id=356587</td>
#       <td>https://www.acingov.pt/acingovprod/2/zonaPublica/zona_publica_c/donwloadProcedurePiece/NjgwNTc4</td>
#       <td>https://www.base.gov.pt/Base4/pt/resultados/?type=doc_documentos&amp;id=2071168&amp;ext=.pdf</td>
#       <td>false</td>
#       <td>72212190-7</td>
#       <td>False</td>
#       <td>None</td>
#       <td>None</td>
#       <td>False</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>Aquisição de serviços</td>
#       <td>Serviços de desenvolvimento de software para ensino</td>
#       <td>Principal</td>
#       <td>113524.8</td>
#       <td>Contratualização de uma Plataforma Educacional de Aprendizagem Digital</td>
#       <td>Não aplicável</td>
#       <td>None</td>
#       <td>Portugal, Santarém, Santarém</td>
#       <td>Não aplicável.</td>
#       <td>Não aplicável.</td>
#       <td>None</td>
#       <td>False</td>
#       <td>False</td>
#       <td>None</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>True</td>
#       <td>None</td>
#       <td>Código dos Contratos Públicos (DL111-B/2017) e Lei n.º 30/2021, de 21.05</td>
#       <td>None</td>
#       <td>None</td>
#       <td>1699382733</td>
#       <td>Município de Santarém</td>
#       <td>505941350</td>
#       <td>https://www.base.gov.pt/Base4/pt/detalhe/?type=entidades&amp;id=1785</td>
#       <td>Porto Editora, S.A.</td>
#       <td>500221103</td>
#       <td>https://www.base.gov.pt/Base4/pt/detalhe/?type=entidades&amp;id=585</td>
#     </tr>
#     <tr>
#       <td>10322139</td>
#       <td>13241/2023</td>
#       <td>592500.00</td>
#       <td>36</td>
#       <td>False</td>
#       <td>6640568</td>
#       <td>13311154</td>
#       <td>2023-08-04</td>
#       <td>151</td>
#       <td>2</td>
#       <td>False</td>
#       <td>False</td>
#       <td>https://dre.pt/application/file/216770781</td>
#       <td>Anúncio de procedimento</td>
#       <td>Concurso público</td>
#       <td>Concurso Público, com Publicidade Internacional, para a Aquisição de Serviços de instalação e manutenção de uma infraestrutura tecnológica em "cloud" de suporte ao sistema de informação aplicacional Oracle da LIPOR</td>
#       <td>2023-11-02</td>
#       <td>2023-11-02</td>
#       <td>521150.00</td>
#       <td>547</td>
#       <td>Associação de Municípios para a Gestão Sustentável de Resíduos do Grande Porto - LIPOR (501394192)(https://www.base.gov.pt/Base4/pt/detalhe/?type=entidades&amp;id=390)</td>
#       <td>Artigo 20.º, n.º 1, alínea a) do Código dos Contratos Públicos</td>
#       <td>OPTIMIZER – SERVIÇOS E CONSULTADORIA INFORMÁTICA, LDA. (504775936)(https://www.base.gov.pt/Base4/pt/detalhe/?type=entidades&amp;id=10540)</td>
#       <td>None</td>
#       <td>https://www.base.gov.pt/Base4/pt/detalhe/?type=anuncios&amp;id=353643</td>
#       <td>https://community.vortal.biz/PRODPublic/Tendering/OpportunityDetail/Index?noticeUID=PT1.NTC.2501553</td>
#       <td>https://www.base.gov.pt/Base4/pt/resultados/?type=doc_documentos&amp;id=2070929&amp;ext=.pdf</td>
#       <td>false</td>
#       <td>72300000-8</td>
#       <td>False</td>
#       <td>None</td>
#       <td>None</td>
#       <td>False</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>Aquisição de serviços</td>
#       <td>Serviços relacionados com dados</td>
#       <td>Principal</td>
#       <td>521150.0</td>
#       <td>Concurso Público, com Publicidade Internacional, para a Aquisição de Serviços de instalação e manutenção de uma infraestrutura tecnológica em "cloud" de suporte ao sistema de informação aplicacional Oracle da LIPOR</td>
#       <td>Não aplicável</td>
#       <td>None</td>
#       <td>Portugal, Porto, Gondomar</td>
#       <td>Não aplicável.</td>
#       <td>Não aplicável.</td>
#       <td>None</td>
#       <td>False</td>
#       <td>False</td>
#       <td>None</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>True</td>
#       <td>None</td>
#       <td>Código dos Contratos Públicos (DL111-B/2017) e Lei n.º 30/2021, de 21.05</td>
#       <td>None</td>
#       <td>None</td>
#       <td>1699384415</td>
#       <td>Associação de Municípios para a Gestão Sustentável de Resíduos do Grande Porto - LIPOR</td>
#       <td>501394192</td>
#       <td>https://www.base.gov.pt/Base4/pt/detalhe/?type=entidades&amp;id=390</td>
#       <td>OPTIMIZER – SERVIÇOS E CONSULTADORIA INFORMÁTICA, LDA.</td>
#       <td>504775936</td>
#       <td>https://www.base.gov.pt/Base4/pt/detalhe/?type=entidades&amp;id=10540</td>
#     </tr>
#     <tr>
#       <td>10324626</td>
#       <td>15934/2023</td>
#       <td>150151.14</td>
#       <td>3</td>
#       <td>False</td>
#       <td>6708714</td>
#       <td>13455812</td>
#       <td>2023-09-25</td>
#       <td>186</td>
#       <td>2</td>
#       <td>False</td>
#       <td>False</td>
#       <td>https://dre.pt/application/file/222052596</td>
#       <td>Anúncio de procedimento</td>
#       <td>Concurso público</td>
#       <td>Concurso público para a aquisição/renovação da manutenção e atualização de licenças  software Microsoft Enterprise Agreement n.º 5124030</td>
#       <td>2023-11-03</td>
#       <td>2023-10-25</td>
#       <td>150436.69</td>
#       <td>366</td>
#       <td>Município de Valongo (501138960)(https://www.base.gov.pt/Base4/pt/detalhe/?type=entidades&amp;id=505)</td>
#       <td>Artigo 20.º, n.º 1, alínea b) do Código dos Contratos Públicos</td>
#       <td>CLARANET II SOLUTIONS, S.A. (510728189)(https://www.base.gov.pt/Base4/pt/detalhe/?type=entidades&amp;id=454083)</td>
#       <td>None</td>
#       <td>https://www.base.gov.pt/Base4/pt/detalhe/?type=anuncios&amp;id=357085</td>
#       <td>https://www.anogov.com/cm-valongo/faces/app/acessoD

# %%
# Contagem do número de ocorrências para os NIFs de entidades adjudicantes
cp.NIF1.value_counts()
# Out:
# NIF1
# 509540716    348
# 508184509     50
# 504322915     33
# 510928374     29
# 510361242     28
#             ...
# 900106590      1
# 501460888      1
# 600084809      1
# 600086992      1
# 600081028      1
# Name: count, Length: 310, dtype: int64

# %%
# Contagem do número de ocorrências para os NIFs de entidades adjudicatárias
cp.NIF2.value_counts()
# Out:
# NIF2
# 504272179         96
# 501774360         85
# 515777048         54
# 502604751         53
# 510728189         43
#                   ..
# 504441361          1
# 502876581          1
# NL856689439B01     1
# 513854363          1
# 507477740          1
# Name: count, Length: 320, dtype: int64

# %%
# Conversão das colunas de data de celebração e publicação em datetime
cp.DataCel = pd.to_datetime(cp.DataCel)
cp.DataPub = pd.to_datetime(cp.DataPub)

# %%
# Número de contratos celebrados em 2023
len(cp[cp['DataCel'].dt.year == 2023])
# Out:
# 718

# %%
# Como há NIFs estrangeiros que contém as letras do país antes do número, temos de comparar strings e não inteiros
cp.NIF1 = cp.NIF1.astype(str)
cp.NIF2 = cp.NIF2.astype(str)

# %%
# Número de contratos públicos celebrados por ano
cp['DataCel'].dt.year.value_counts().sort_index(ascending = False)
# Out:
# DataCel
# 2023    718
# 2022    624
# 2021     10
# 2020      2
# 2019      2
# 2018      2
# Name: count, dtype: int64

# %%
# Número de contratos públicos ganhos em 2023 pela empresa com o NIF abaixo
print('Número de concursos públicos ganhos por 504272179 em 2023 :', len(cp[(cp['DataCel'].dt.year == 2023) & (cp.NIF2 == '504272179')]))

# Conjunto de contratos públicos ganhos em 2023 pela empresa com o NIF abaixo
cp[(cp['DataCel'].dt.year == 2023) & (cp.NIF2 == '504272179')]
# Out:
# Número de concursos públicos ganhos por 504272179 em 2023 : 47
#             ID   NrAnuncio   PrecoBase Prazo      4        5         6  \
# 25    10281794   9595/2023   420470.40    30  False  6552489  13125722
# 27    10281057   8459/2023   107800.00    30  False  6512068  13055469
# 41    10285595  10233/2023   300162.60    30  False  6564975  13159433
# 71    10312468   8575/2023   218880.00    30  False  6514152  13060399
# 79    10312472   8459/2023   107800.00    30  False  6512068  13055469
# 106   10223856   8463/2023   109440.00    30  False  6512065  13055459
# 128   10339729  11232/2023   122666.67    30  False  6584775  13205397
# 133   10338918  11232/2023   122666.67    30  False  6584775  13205397
# 151   10256440   6876/2023   650000.00    30  False  6468178  12957911
# 159   10261915   8575/2023   218880.00    30  False  6514152  13060399
# 169   10170971   9759/2022  1623777.12    30  False  6021542  12053653
# 216   10204451   7588/2023    98437.50    30  False  6493340  13003268
# 217   10204302   7587/2023   183260.00    30  False  6493311  13003200
# 230   10210919   5066/2023   595939.20    30  False  6422304  12860169
# 261   10113116   5829/2023   299202.00    30  False  6445165  12905352
# 278   10146094   1132/2023   196200.00    19  False  6495958  13008699
# 292   10156370   4147/2023   318560.00    30  False  6399892  12808431
# 306   10161710   7587/2023   183260.00    30  False  6493311  13003200
# 308   10161511   7678/2023   364651.16    30  False  6495854  13008455
# 494   2023-02-17   35  2  ...
# 542   2023-02-09   29  2  ...
# 560   2022-11-02  211  2  ...
# 672   2023-01-31   22  2  ...
# 684   2022-12-13  238  2  ...
# 960   2023-04-20   78  2  ...
# 961   2023-04-20   78  2  ...
# 964   2023-05-11   91  2  ...
# 1016  2023-05-12   92  2  ...
# 1024  2023-09-04  171  2  ...
#
#                                                      57  \
# 25    Código dos Contratos Públicos (DL111-B/2017) e...
# 27    Código dos Contratos Públicos (DL111-B/2017) e...
# 41    Código dos Contratos Públicos (DL111-B/2017) e...
# 71    Código dos Contratos Públicos (DL111-B/2017) e...
# 79    Código dos Contratos Públicos (DL111-B/2017) e...
# 106   Código dos Contratos Públicos (DL111-B/2017) e...
# 128   Código dos Contratos Públicos (DL111-B/2017) e...
# 133   Código dos Contratos Públicos (DL111-B/2017) e...
# 151   Código dos Contratos Públicos (DL111-B/2017) e...
# 159   Código dos Contratos Públicos (DL111-B/2017) e...
# 169   Código dos Contratos Públicos (DL111-B/2017) e...
# 216   Código dos Contratos Públicos (DL111-B/2017) e...
# 217   Código dos Contratos Públicos (DL111-B/2017) e...
# 230   Código dos Contratos Públicos (DL111-B/2017) e...
# 261   Código dos Contratos Públicos (DL111-B/2017) e...
# 278   Código dos Contratos Públicos (DL111-B/2017) e...
# 292   Código dos Contratos Públicos (DL111-B/2017) e...
# 306   Código dos Contratos Públicos (DL111-B/2017) e...
# 308   Código dos Contratos Públicos (DL111-B/2017) e...
# 318   Código dos Contratos Públicos (DL111-B/2017) e...
# 320   Código dos Contratos Públicos (DL111-B/2017) e...
# 331   Código dos Contratos Públicos (DL111-B/2017) e...
# 333   Código dos Contratos Públicos (DL111-B/2017) e...
# 334   Código dos Contratos Públicos (DL111-B/2017) e...
# 400   Código dos Contratos Públicos (DL111-B/2017) e...
# 401   Código dos Contratos Públicos (DL111-B/2017) e...
# 407   Código dos Contratos Públicos (DL111-B/2017) e...
# 408   Código dos Contratos Públicos (DL111-B/2017) e...
# 410   Código dos Contratos Públicos (DL111-B/2017) e...
# 422   Código dos Contratos Públicos (DL111-B/2017) e...
# 423   Código dos Contratos Públicos (DL111-B/2017) e...
# 424   Código dos Contratos Públicos (DL111-B/2017) e...
# 425   Código dos Contratos Públicos (DL111-B/2017) e...
# 428   Código dos Contratos Públicos (DL111-B/2017) e...
# 429   Código dos Contratos Públicos (DL111-B/2017) e...
# 484   Código dos Contratos Públicos (DL111-B/2017) e...
# 491   Código dos Contratos Públicos (DL111-B/2017) e...
# 494   Código dos Contratos Públicos (DL111-B/2017) e...
# 542   Código dos Contratos Públicos (DL111-B/2017) e...
# 560   Código dos Contratos Públicos (DL111-B/2017) e...
# 672   Código dos Contratos Públicos (DL111-B/2017) e...
# 684   Código dos Contratos Públicos (DL111-B/2017) e...
# 960   Código dos Contratos Públicos (DL111-B/2017) e...
# 961   Código dos Contratos Públicos (DL111-B/2017) e...
# 964   Código dos Contratos Públicos (DL111-B/2017) e...
# 1016  Código dos Contratos Públicos (DL111-B/2017) e...
# 1024  Código dos Contratos Públicos (DL111-B/2017) e...
# 407    Capgemini Portugal, S.A.  504272179
# 408    Capgemini Portugal, S.A.  504272179
# 410    Capgemini Portugal, S.A.  504272179
# 422    Capgemini Portugal, S.A.  504272179
# 423    Capgemini Portugal, S.A.  504272179
# 424    Capgemini Portugal, S.A.  504272179
# 425    Capgemini Portugal, S.A.  504272179
# 428    Capgemini Portugal, S.A.  504272179
# 429    CAPGEMINI PORTUGAL, S.A.  504272179
# 484    CAPGEMINI PORTUGAL, S.A.  504272179
# 491    CAPGEMINI PORTUGAL, S.A.  504272179
# 494    CAPGEMINI PORTUGAL, S.A.  504272179
# 542    CAPGEMINI PORTUGAL, S.A.  504272179
# 560    CAPGEMINI PORTUGAL, S.A.  504272179
# 672    CAPGEMINI PORTUGAL, S.A.  504272179
# 684    CAPGEMINI PORTUGAL, S.A.  504272179
# 960   CAPGEMINI PORTUGAL, S.A.,  504272179
# 961   CAPGEMINI PORTUGAL, S.A.,  504272179
# 964    Capgemini Portugal, S.A.  504272179
# 1016   Capgemini Portugal, S.A.  504272179
# 1024   Capgemini Portugal, S.A.  504272179
#
#                                                    URL2
# 25    https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 27    https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 41    https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 71    https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 79    https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 106   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 128   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 133   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 151   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 159   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 169   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 216   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 217   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 230   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 261   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 278   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 292   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 306   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 308   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 318   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 320   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 331   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 333   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 334   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 400   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 401   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 407   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 408   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 410   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 422   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 423   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 424   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 425   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 428   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 429   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 484   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 491   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 494   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 542   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 560   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 672   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 684   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 960   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 961   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 964   https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 1016  https://www.base.gov.pt/Base4/pt/detalhe/?type...
# 1024  https://www.base.gov.pt/Base4/pt/detalhe/?type...
#
# [47 rows x 67 columns]

# %%
def nr_contrato(df,ano,nif):
    """
    Função que retorna o número de contratos celebrados/ganhos por uma determinada entidade adjudicatária num determinado ano

    Parâmetros:
         df : dataframe que contém o conjunto de contratos públicos
        ano : ano em que estamos interessados o número de contratos celebrados pela entidade
        nif : nif da entidade

    return:
        int : número de contratos públicos celebrados pela entidade com NIF=nif no ano de 'ano'
    """

    nr_cont = df[(df['DataCel'].dt.year == ano) & (df.NIF2 == nif)]

    return len(nr_cont)

# %%
nr_contrato(cp,2023,'504272179')
# Out:
# 47

# %% [markdown]
# ### Análise dos Concursos Ganhos por entidade adjudicatária em 2022 e 2023

# %%
print("Número de contratos públicos atribuídos ao conjunto de entidades adjudicatárias\n\n    NIF \t Nr de Contratos 2023 \t Número de Contratos 2022 \n")

for i in (cp.NIF2.value_counts().index):
    print(i,'\t\t', nr_contrato(cp,2023,i), '\t\t\t', nr_contrato(cp,2022,i))
# Out:
# Número de contratos públicos atribuídos ao conjunto de entidades adjudicatárias
#
#     NIF 	 Nr de Contratos 2023 	 Número de Contratos 2022
#
# 504272179 		 47 			 49
# 501774360 		 32 			 53
# 515777048 		 38 			 16
# 502604751 		 14 			 39
# 510728189 		 30 			 13
# 980079659 		 20 			 18
# 506360237 		 22 			 15
# 502726890 		 18 			 12
# 504615947 		 12 			 11
# 515371378 		 18 			 0
# 505134195 		 6 			 12
# 509937349 		 8 			 9
# 513942696 		 1 			 0
# 502446170 		 1 			 0
# 506097250 		 1 			 0
# 503844276 		 1 			 0
# 504995634 		 1 			 0
# 514519606 		 1 			 0
# 501506543 		 1 			 0
# 515577022 		 1 			 0
# 509643531 		 1 			 0
# 510474357 		 1 			 0
# 513662332 		 1 			 0
# 506396010 		 1 			 0
# 507714580 		 0 			 1
# nan 		 1 			 0
# 513509593 		 1 			 0
# 503731765 		 1 			 0
# 515979899 		 1 			 0
# 514535466 		 0 			 1
# 514840960 		 1 			 0
# 508646103 		 1 			 0
# 505141019 		 0 			 1
# 515163724 		 0 			 1
# 504673734 		 1 			 0
# 510822304 		 1 			 0
# 500433615 		 1 			 0
# 502420227 		 0 			 1
# 507969332 		 1 			 0
# 501570691 		 1 			 0
# 513609687 		 1 			 0
# 516064932 		 1 			 0
# 505767457 		 1 			 0
# 509656510 		 0 			 1
# 503000140 		 1 			 0
# 513591168 		 1 			 0
# 515915017 		 1 			 0
# 510785484 		 1 			 0
# 513880798 		 1 			 0
# 503027952 		 1 			 0
# NL005033019B01 		 1 			 0
# 509381219 		 1 			 0
# 513872442 		 1 			 0
# 516117785 		 1 			 0
# 505402920 		 1 			 0
# 513462546 		 1 			 0
# 505355760 		 0 			 0
# 503419710 		 1 			 0
# 508959152 		 0 			 0
# 514509040 		 1 			 0
# 513813713 		 1 			 0
# 502280859 		 1 			 0
# 507812212 		 1 			 0
# 504308289 		 1 			 0
# 502869178 		 1 			 0
# 513742573 		 1 			 0
# 506593428 		 1 			 0
# 505385864 		 0 			 1
# 516541307 		 0 			 1
# 514855398 		 1 			 0
# 515222631 		 1 			 0
# 514756969 		 1 			 0
# 507184181 		 1 			 0
# 503291137 		 0 			 1
# ESB39024732 		 1 			 0
# 513950621 		 1 			 0
# 509465102 		 0 			 0
# 505722267 		 1 			 0
# 514519215 		 1 			 0
# 502665696 		 1 			 0
# 506043576 		 1 			 0
# 505192080 		 1 			 0
# 516584960 		 1 			 0
# 504990926 		 1 			 0
# ESB42519520 		 1 			 0
# 504143603 		 0 			 1
# 504073206 		 1 			 0
# 507246152 		 1 			 0
# 500077568 		 1 			 0
# 513854363 		 1 			 0
# 515352560 		 1 			 0
# B85765766 		 1 			 0
# 505248948 		 1 			 0
# 510130968 		 1 			 0
# 508919061 		 1 			 0
# 513779132 		 1 			 0
# 504441361 		 1 			 0
# 502876581 		 1 			 0
# NL856689439B01 		 1 			 0
# 507477740 		 1 			 0

# %%
# Determinar, para o ano de 2023, o número total de concursos públicos celebrados e o número médio de 
# contratos celebrados por entidade adjudicante
cp[cp.DataCel.dt.year == 2023].NIF2.value_counts().describe()
# Out:
# count    234.000000
# mean       3.068376
# std        5.469740
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        3.000000
# max       47.000000
# Name: count, dtype: float64

# %%
v = pd.Series(cp[cp.DataCel.dt.year == 2023].NIF2.value_counts()).value_counts()

plt.bar(v.index, v.values)
plt.xlabel('Número de Concursos Ganhos')
plt.ylabel('Ocorrências')
plt.title('Ano 2023')
plt.show()

# %%
# Determinar, para o ano de 2022, o número total de concursos públicos celebrados e o número médio de 
# contratos celebrados por entidade adjudicante
cp[cp.DataCel.dt.year == 2022].NIF2.value_counts().describe()
# Out:
# count    187.000000
# mean       3.336898
# std        6.477328
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        3.000000
# max       53.000000
# Name: count, dtype: float64

# %%
v = pd.Series(cp[cp.DataCel.dt.year == 2022].NIF2.value_counts()).value_counts()

plt.bar(v.index, v.values)
plt.xlabel('Número de Concursos Ganhos')
plt.ylabel('Ocorrências')
plt.title('Ano 2022')
plt.show()

# %% [markdown]
# <br>
#
# <br>
#
# <br>
#
# ***
#
# ## Gerar flag para todos os contratos públicos ganhos por uma determinada entidade adjudicatária que tenha excedido um treshold de concursos ganhos
#
# Para cada NIF das entidades adjudicatárias, verificar quantos contratos públicos venceu num determinado ano.
#
# Se o número de contratos ganhos for superior a um determinado treshold é ativada uma flag em todos os contratos celebrados com esta entidade.
#
# Inicialmente, este treshold é definido pelo valor médio de concursos ganhos por entidade adjudicatária
#
#
# <br>
#
# **Ano 2023 :**

# %%
# Média de concursos públicos ganhos por entidade adjudicante a nível nacional
avg = cp[cp.DataCel.dt.year == 2022].NIF2.value_counts().mean()

# Índices dos NIFs2 cujo número de contratos celebrados é superior à media nacional de contratos celebrados
IDx = np.where(cp[cp.DataCel.dt.year == 2022].NIF2.value_counts() > avg)[0]

# %%
cp[cp.DataCel.dt.year == 2022].NIF2.value_counts().describe()
# Out:
# count    187.000000
# mean       3.336898
# std        6.477328
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        3.000000
# max       53.000000
# Name: count, dtype: float64

# %%
# NIFs das entidades adjudicatórias que venceram, no ano de 2022, mais do que a média de concursos a nível nacional
NIFs = cp[cp.DataCel.dt.year == 2022].NIF2.value_counts().index[IDx]
NIFs
# Out:
# Index(['501774360', '504272179', '502604751', '980079659', '515777048',
#        '510830536', '506360237', '510728189', '503670693', '502726890',
#        '505134195', '504615947', '504729624', '502544180', '504551221',
#        '509937349', '506210855', '504243926', '508775876', '503182710',
#        '510874169', '503541320', '506204650', '503222364', '502309440',
#        '504099388', '510098711', '501782230', '513600728', '508776058',
#        '502479418', '503239917', '503536717', '505244713', '505355108',
#        '509216595', '502980826', '501989978', '509733441', '504654748'],
#       dtype='object', name='NIF2')

# %%
flag_ids = []

for i in NIFs:
    ids = cp[(cp.DataCel.dt.year == 2022) & (cp.NIF2 == i)].ID.tolist()
    flag_ids.extend(ids)
flag_ids
# Out:
# ['9448728',
#  '10238348',
#  '10063214',
#  '9889575',
#  '9695707',
#  '9599981',
#  '9599980',
#  '9602615',
#  '9602542',
#  '9602195',
#  '9600900',
#  '9600738',
#  '9605956',
#  '9605951',
#  '9604483',
#  '9608196',
#  '9608195',
#  '9610340',
#  '9610332',
#  '9616343',
#  '9616339',
#  '9618999',
#  '9618884',
#  '9622120',
#  '9622113',
#  '9624511',
#  '9624510',
#  '9624496',
#  '9624493',
#  '9624490',
#  '9624481',
#  '9624478',
#  '9624460',
#  '9624449',
#  '9624401',
#  '9624300',
#  '9582096',
#  '9582065',
#  '9586728',
#  '9586681',
#  '9593787',
#  '9593785',
#  '9596095',
#  '9596011',
#  '9394070',
#  '9392954',
#  '9500426',
#  '9327145',
#  '9373426',
#  '9378399',
#  '10169131',
#  '9881382',
#  '9672800',
#  '9700192',
#  '9532253',
#  '9567963',
#  '9574282',
#  '9405601',
#  '9419094',
#  '9268154',
#  '9279389',
#  '9350965',
#  '9427066',
#  '9829868',
#  '9702903',
#  '9636168',
#  '9560079',
#  '9456123',
#  '9517618',
#  '9518074',
#  '9277532',
#  '9338406',
#  '9377945',
#  '9665171',
#  '9610402',
#  '9610399',
#  '9616352',
#  '9616349',
#  '9619135',
#  '9624509',
#  '9624505',
#  '9624487',
#  '9624432',
#  '9635036',
#  '9424326',
#  '9711915',
#  '9720770',
#  '9597040',
#  '9652629',
#  '9486912',
#  '9267267',
#  '9274236',
#  '9376154',
#  '9384935',
#  '10064025',
#  '9621570',
#  '9536006',
#  '9593816',
#  '9413071',
#  '9452639',
#  '9486350',
#  '9516953',
#  '9332199',
#  '9425860',
#  '9426666',
#  '9683730',
#  '9610406',
#  '9624508',
#  '9624486',
#  '9404990',
#  '9481321',
#  '9501901',
#  '9430883',
#  '9722720',
#  '9607494',
#  '9636626',
#  '9551938',
#  '9394517',
#  '9398912',
#  '9484310',
#  '9665188',
#  '9669453',
#  '9624518',
#  '9624378',
#  '9636192',
#  '9267853',
#  '9349306',
#  '9390001',
#  '9433230',
#  '9441695',
#  '9693080',
#  '9534346',
#  '9508616',
#  '9528363',
#  '9328095',
#  '9423257',
#  '10335881',
#  '9437987',
#  '9402147',
#  '9404925',
#  '9456096',
#  '9324293',
#  '9686356',
#  '9545448',
#  '9404564',
#  '9413807',
#  '9476217',
#  '9525846',
#  '9386636',
#  '9601067',
#  '9557063',
#  '9557051',
#  '9557035',
#  '9557023',
#  '9316658',
#  '9686688',
#  '9211019',
#  '9348990',
#  '9378241',
#  '9378217',
#  '10063055',
#  '9580691',
#  '9580069',
#  '9407351',
#  '9457761',
#  '9459967',
#  '9304430',
#  '9305475',
#  '9390723',
#  '9390552',
#  '9599046',
#  '9452703',
#  '9464192',
#  '9379599',
#  '9382409',
#  '9443261',
#  '9624524',
#  '9624523',
#  '9629381',
#  '9586619',
#  '9605963',
#  '9621349',
#  '9490513',
#  '9490208',
#  '9324575',
#  '9664681',
#  '9605992',
#  '9518145',
#  '9391550',
#  '9391472',
#  '9748277',
#  '9725524',
#  '9591565',
#  '9399384',
#  '9381724',
#  '10110265',
#  '9726472',
#  '9419080',
#  '9215862',
#  '9249131',
#  '9664403',
#  '9692919',
#  '9606263',
#  '9417966',
#  '9276254',
#  '9276059',
#  '9315999',
#  '9377103',
#  '9633947',
#  '9254587',
#  '9291844',
#  '9374299',
#  '9444046',
#  '9918140',
#  '9550361',
#  '9550354',
#  '9696607',
#  '9498980',
#  '9301797',
#  '9351664',
#  '9596954',
#  '9634979',
#  '9532678',
#  '9374886',
#  '9425230',
#  '9221413',
#  '9263068',
#  '9272790',
#  '9248758',
#  '9248720',
#  '9248692',
#  '9254144',
#  '9288472',
#  '9298816',
#  '9301201',
#  '9309684']

# %% [markdown]
# ### Filtrar por Distrito
#
# Calcular o número médio de concursos ganhos por entidade adjudicante por distrito
#
# **1 : Criar uma coluna da dataframe com o distrito**

# %%
cp = cp.rename(columns={45:'Local'})
cp['Distrito'] = cp['Local'].str.split(', ').str[1]

h(cp.head(1))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>ID</th>
#       <th>NrAnuncio</th>
#       <th>PrecoBase</th>
#       <th>Prazo</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>10</th>
#       <th>11</th>
#       <th>12</th>
#       <th>13</th>
#       <th>14</th>
#       <th>15</th>
#       <th>DataPub</th>
#       <th>DataCel</th>
#       <th>PrecoContratual</th>
#       <th>19</th>
#       <th>Adjudicante</th>
#       <th>21</th>
#       <th>Adjudicatária</th>
#       <th>EntConcorrentes</th>
#       <th>24</th>
#       <th>25</th>
#       <th>26</th>
#       <th>27</th>
#       <th>28</th>
#       <th>29</th>
#       <th>30</th>
#       <th>31</th>
#       <th>32</th>
#       <th>33</th>
#       <th>34</th>
#       <th>35</th>
#       <th>36</th>
#       <th>37</th>
#       <th>38</th>
#       <th>39</th>
#       <th>40</th>
#       <th>41</th>
#       <th>42</th>
#       <th>43</th>
#       <th>44</th>
#       <th>Local</th>
#       <th>46</th>
#       <th>47</th>
#       <th>48</th>
#       <th>49</th>
#       <th>50</th>
#       <th>51</th>
#       <th>52</th>
#       <th>53</th>
#       <th>54</th>
#       <th>55</th>
#       <th>56</th>
#       <th>57</th>
#       <th>58</th>
#       <th>59</th>
#       <th>60</th>
#       <th>EntidadeAdjudicante</th>
#       <th>NIF1</th>
#       <th>URL1</th>
#       <th>EntidadeAdjudicataria</th>
#       <th>NIF2</th>
#       <th>URL2</th>
#       <th>Distrito</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10323405</td>
#       <td>15555/2023</td>
#       <td>137670.0</td>
#       <td>6</td>
#       <td>False</td>
#       <td>6699898</td>
#       <td>13437191</td>
#       <td>2023-09-19</td>
#       <td>182</td>
#       <td>2</td>
#       <td>False</td>
#       <td>False</td>
#       <td>https://dre.pt/application/file/221829278</td>
#       <td>Anúncio de procedimento</td>
#       <td>Concurso público</td>
#       <td>Contratualização de uma Plataforma Educacional de Aprendizagem Digital</td>
#       <td>2023-11-02</td>
#       <td>2023-10-31</td>
#       <td>113524.8</td>
#       <td>332</td>
#       <td>Município de Santarém (505941350)(https://www.base.gov.pt/Base4/pt/detalhe/?type=entidades&amp;id=1785)</td>
#       <td>Artigo 20.º, n.º 1, alínea b) do Código dos Contratos Públicos</td>
#       <td>Porto Editora, S.A. (500221103)(https://www.base.gov.pt/Base4/pt/detalhe/?type=entidades&amp;id=585)</td>
#       <td>None</td>
#       <td>https://www.base.gov.pt/Base4/pt/detalhe/?type=anuncios&amp;id=356587</td>
#       <td>https://www.acingov.pt/acingovprod/2/zonaPublica/zona_publica_c/donwloadProcedurePiece/NjgwNTc4</td>
#       <td>https://www.base.gov.pt/Base4/pt/resultados/?type=doc_documentos&amp;id=2071168&amp;ext=.pdf</td>
#       <td>false</td>
#       <td>72212190-7</td>
#       <td>False</td>
#       <td>None</td>
#       <td>None</td>
#       <td>False</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>False</td>
#       <td>Aquisição de serviços</td>
#       <td>Serviços de desenvolvimento de software para ensino</td>
#       <td>Principal</td>
#       <td>113524.8</td>
#       <td>Contratualização de uma Plataforma Educacional de Aprendizagem Digital</td>
#       <td>Não aplicável</td>
#       <td>None</td>
#       <td>Portugal, Santarém, Santarém</td>
#       <td>Não aplicável.</td>
#       <td>Não aplicável.</td>
#       <td>None</td>
#       <td>False</td>
#       <td>False</td>
#       <td>None</td>
#       <td>None</td>
#       <td>False</td>
#       <td>None</td>
#       <td>True</td>
#       <td>None</td>
#       <td>Código dos Contratos Públicos (DL111-B/2017) e Lei n.º 30/2021, de 21.05</td>
#       <td>None</td>
#       <td>None</td>
#       <td>1699382733</td>
#       <td>Município de Santarém</td>
#       <td>505941350</td>
#       <td>https://www.base.gov.pt/Base4/pt/detalhe/?type=entidades&amp;id=1785</td>
#       <td>Porto Editora, S.A.</td>
#       <td>500221103</td>
#       <td>https://www.base.gov.pt/Base4/pt/detalhe/?type=entidades&amp;id=585</td>
#       <td>Santarém</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **2 : Listar distritos com maior número de contratos celebrados**

# %%
cp.Distrito.value_counts()
# Out:
# Distrito
# Lisboa                        598
# Porto                         194
# Porto<BR/>Portugal             92
# Lisboa<BR/>Portugal            77
# Setúbal                        38
# Braga                          25
# Aveiro                         21
# Coimbra                        21
# Castelo Branco                 17
# Região Autónoma da Madeira     14
# Viseu                          13
# Vila Real                      13
# Faro                           12
# Viana do Castelo               11
# Santarém                       11
# Leiria                         10
# Distrito não determinado       10
# Região Autónoma dos Açores      9
# Braganca                        9
# Évora                           8
# Beja                            6
# Portugal Continental            6
# Guarda                          4
# Portalegre                      3
# Viseu<BR/>Portugal              1
# Name: count, dtype: int64

# %%
cp['Distrito'] = cp['Distrito'].str.replace('Porto<BR/>Portugal', 'Porto')
cp['Distrito'] = cp['Distrito'].str.replace('Lisboa<BR/>Portugal', 'Lisboa')
cp['Distrito'] = cp['Distrito'].str.replace('Viseu<BR/>Portugal', 'Viseu')

# %%
cp.Distrito.value_counts()
# Out:
# Distrito
# Lisboa                        675
# Porto                         286
# Setúbal                        38
# Braga                          25
# Aveiro                         21
# Coimbra                        21
# Castelo Branco                 17
# Região Autónoma da Madeira     14
# Viseu                          14
# Vila Real                      13
# Faro                           12
# Santarém                       11
# Viana do Castelo               11
# Distrito não determinado       10
# Leiria                         10
# Região Autónoma dos Açores      9
# Braganca                        9
# Évora                           8
# Beja                            6
# Portugal Continental            6
# Guarda                          4
# Portalegre                      3
# Name: count, dtype: int64

# %%
#h(cp.loc[cp['Distrito'] == 'Portugal Continental'])

# %%
plt.boxplot(cp.PrecoContratual,showfliers=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f0bf39d27d0>,
#   <matplotlib.lines.Line2D at 0x7f0bf3e3e690>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f0bf3e3efd0>,
#   <matplotlib.lines.Line2D at 0x7f0bf3e3f850>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f0bf3e12ed0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0bf3e50110>],
#  'fliers': [],
#  'means': []}

# %%
cp.PrecoContratual.describe()/10**3
# Out:
# count        1.358000
# mean       285.659743
# std        889.796361
# min          0.000000
# 25%         54.681555
# 50%        113.390400
# 75%        248.553340
# max      24000.000000
# Name: PrecoContratual, dtype: float64

# %%
print(np.quantile(cp.PrecoContratual,0.8), np.quantile(cp.PrecoContratual,0.85), np.quantile(cp.PrecoContratual,0.9), np.quantile(cp.PrecoContratual,0.¨))
# Out:
# 308800.8000000003 399550.221 557030.0399999999 749755.4095

# %% [markdown]
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>

# %%
# Construir nova dataframe a partir da original mas que contenha apenas as colunas com EntAdjudicante, EntAdjudicatária e respetivos NIF's
# referente ao ano de 2023
novadf = cp.loc[cp['DataCel'].dt.year == 2023, ['ID','NrAnuncio','EntidadeAdjudicante','NIF1','EntidadeAdjudicataria','NIF2']]
novadf
# Out:
#             ID   NrAnuncio                                EntidadeAdjudicante  \
# 0     10323405  15555/2023                              Município de Santarém
# 1     10322139  13241/2023  Associação de Municípios para a Gestão Sustent...
# 2     10324626  15934/2023                               Município de Valongo
# 3     10325177   1698/2023  EMEL - Empresa Municipal de Mobilidade e Estac...
# 5     10327340   7629/2023                 Instituto Politécnico de Bragança
# ...        ...         ...                                                ...
# 1348  10377550  11864/2023           iRN - Instituto dos Registos e Notariado
# 1351  10376734   2305/2023         Secretaria-Geral do Ministério da Economia
# 1352  10376541  19394/2023            Ministério da Defesa Nacional - Marinha
# 1353  10376333   2340/2023   Instituto de Gestão Financeira da Educação, I.P.
# 1355  10376227  18381/2023  Estrutura de Missão para a Extensão da Platafo...
#
#            NIF1                              EntidadeAdjudicataria       NIF2
# 0     505941350                                Porto Editora, S.A.  500221103
# 1     501394192  OPTIMIZER – SERVIÇOS E CONSULTADORIA INFORMÁTI...  504775936
# 2     501138960                        CLARANET II SOLUTIONS, S.A.  510728189
# 3     503311332                         CLARANET II SOLUTIONS, S.A  510728189
# 5     600013758             Quidgest - Consultores de Gestão, S.A.  501989978
# ...         ...                                                ...        ...
# 1348  508184258               AXIANSEU II DIGITAL CONSULTING, S.A.  501774360
# 1351  600081125              Reload - Consultoria Informática, Lda  506210855
# 1352  600012662                                  INETUM ESPAÑA  SA  980079659
# 1353  600086631  Normática, Serviços de Informática e Organizaç...  501782230
# 1355  600081028  Konica Minolta Business Solutions Portugal, Un...  502120070
#
# [718 rows x 6 columns]

# %%
# Print dos NIF's por ordem decrescente de ocorrência
print(novadf.NIF1.value_counts(), '\n\n')
print(novadf.NIF2.value_counts())
# Out:
# NIF1
# 509540716    163
# 504322915     22
# 510928374     16
# 501442600     13
# 600084779     11
#             ...
# 600082628      1
# 680009671      1
# 507142217      1
# 515545180      1
# 600081028      1
# Name: count, Length: 228, dtype: int64
#
#
# NIF2
# 504272179    47
# 515777048    38
# 501774360    32
# 510728189    30
# 506360237    22
#              ..
# 510474357     1
# 513662332     1
# 506396010     1
# 507321707     1
# 507477740     1
# Name: count, Length: 234, dtype: int64

# %%
# Ordenar nova dataframe por ordem decrescente de ocorrência do NIF1 ( nif da entidade adjudicante ) 
ordem = novadf['NIF1'].value_counts().index
novadf = novadf.sort_values(by='NIF1', key=lambda x: pd.Categorical(x, categories = ordem), ignore_index=True)

# %%
novadf
# Out:
#            ID   NrAnuncio                                EntidadeAdjudicante  \
# 0    10103391   3295/2023  SPMS - Serviços Partilhados do Ministério da S...
# 1    10170890   7679/2023  SPMS- Serviços Partilhados do M. da Saúde, E.P.E.
# 2    10170852   6522/2023  SPMS - Serviços Partilhados do Ministério da S...
# 3    10170815   6522/2023  SPMS - Serviços Partilhados do Ministério da S...
# 4    10170466   7588/2023  SPMS - Serviços Partilhados do Ministério da S...
# ..        ...         ...                                                ...
# 713  10157315   9009/2023          Serviços Sociais da Administração Pública
# 714  10155193   7511/2023  Serviços Intermunicipalizados de Águas e Resíd...
# 715  10152400   5043/2023    Fagar - Faro, Gestão de Águas e Resíduos, E. M.
# 716  10153287   5107/2023                            Hospital de Braga, EPE
# 717  10376227  18381/2023  Estrutura de Missão para a Extensão da Platafo...
#
#           NIF1                              EntidadeAdjudicataria       NIF2
# 0    509540716                            Amazon Informática, Lda  516411810
# 1    509540716  INDRA III SOLUÇÕES DE TECNOLOGIA DA INFORMAÇÃO...  503222364
# 2    509540716                     MARCOS BARROSA, UNIPESSOAL LDA  515371378
# 3    509540716  INDRA III SOLUÇÕES DE TECNOLOGIA DA INFORMAÇÃO...  503222364
# 4    509540716                                    Shore Spun Lda.  507902238
# ..         ...                                                ...        ...
# 713  600082628              Deloitte Processes & Operations, S.A.  502446170
# 714  680009671                            CLARANET PORTUGAL, S.A.  503412031
# 715  507142217           Visionware, Sistemas de Informação, S.A.  507411072
# 716  515545180                       BIQ - HEALTH SOLUTIONS, LDA.  504105337
# 717  600081028  Konica Minolta Business Solutions Portugal, Un...  502120070
#
# [718 rows x 6 columns]

# %%
# Verificar, para o NIF1 com maior número de ocorrências, o número de contratos celebrados com cada um dos NIFs das entidades adjudicatárias
# Imprimir apenas para nr de contratos celebrados acima de 5
contagem = novadf.loc[novadf['NIF1'] == '509540716','NIF2'].value_counts()
contagem[contagem > 5].index
# Out:
# Index(['504272179', '515777048', '515371378', '501774360', '506360237',
#        '503222364', '510098711'],
#       dtype='object', name='NIF2')

# %%
for i in novadf.NIF1.value_counts().index:

    cont = novadf.loc[novadf['NIF1'] == i,'NIF2'].value_counts()

    if len(cont[cont > 5].values):
        print('NIF1 =',i)
        print(cont[cont > 5])
        print('\n\n')

    for j in cont[cont > 5].index:
        print(novadf.ID.loc[(novadf['NIF1'] == i) & (novadf['NIF2'] == j)])
        print('\n\n')
        
    cont = 0
# Out:
# NIF1 = 509540716
# NIF2
# 504272179    39
# 515777048    31
# 515371378    18
# 501774360    16
# 506360237     9
# 503222364     8
# 510098711     6
# Name: count, dtype: int64
#
#
#
# 7      10168662
# 9      10168812
# 16     10161511
# 17     10161710
# 18     10170971
# 19     10311809
# 24     10035765
# 28     10035502
# 33     10261915
# 34     10058804
# 35     10059039
# 38     10059100
# 45     10204451
# 46     10204302
# 53      9830082
# 77     10113116
# 82      9825462
# 83     10009799
# 86     10101016
# 87     10101046
# 88     10101077
# 89     10101118
# 100    10312468
# 104    10100889
# 105    10281057
# 113    10228788
# 116    10230288
# 117     9960977
# 118    10230326
# 122    10281794
# 125    10338918
# 126    10099601
# 128    10099668
# 129    10223856
# 141    10339729
# 148    10095824
# 149    10312472
# 152    10095769
# 159    10099869
# Name: ID, dtype: object
#
#
#
# 8      10168757
# 15     10161447
# 21     10059125
# 23     10035794
# 26     10035600
# 27     10035549
# 29     10035372
# 30     10035314
# 32     10261946
# 36     10059063
# 39     10059157
# 41     10161771
# 56     10103347
# 59     10103445
# 60     10106119
# 62      9830038
# 63      9934338
# 73      9912692
# 79     10113260
# 80     10113284
# 81      9934317
# 110     9963255
# 111     9963281
# 136    10230212
# 138    10080885
# 142    10339365
# 143     9824923
# 146     9830201
# 150    10337509
# 158    10338678
# 160    10338639
# Name: ID, dtype: object
#
#
#
# 2      10170852
# 42     10162119
# 48     10204260
# 49     10204230
# 64     10162178
# 67     10188319
# 68     10188301
# 69     10188270
# 84     10338995
# 90     10101151
# 91     10102322
# 103    10230635
# 114    10312460
# 119    10230493
# 123    10230582
# 127    10337213
# 134     9997215
# 137    10265100
# Name: ID, dtype: object
#
#
#
# 40     10010325
# 47     10103294
# 54     10103327
# 92     10102514
# 94     10223875
# 97      9991342
# 99      9991266
# 101    10312461
# 130     9995991
# 132     9995931
# 133     9995895
# 151    10095989
# 155     9996671
# 156     9996663
# 157     9996648
# 161     9996682
# Name: ID, dtype: object
#
#
#
# 5      10170419
# 14     10161129
# 65     10280375
# 93     10371571
# 106     9974496
# 109     9962255
# 112     9959212
# 145    10337405
# 154    10096038
# Name: ID, dtype: object
#
#
#
# 1      10170890
# 3      10170815
# 25     10070491
# 85     10100993
# 98     10099495
# 102    10100959
# 115    10229934
# 153    10311506
# Name: ID, dtype: object
#
#
#
# 6      9915245
# 10     9915243
# 11    10281825
# 12    10281770
# 13     9915241
# 31    10058837
# Name: ID, dtype: object
#
#
#
# NIF1 = 504322915
# NIF2
# 502726890    6
# Name: count, dtype: int64
#
#
#
# 164     9953348
# 166    10065913
# 173     9990308
# 174     9978142
# 177     9881015
# 180    10256261
# Name: ID, dtype: object
#
#
#
# NIF1 = 510928374
# NIF2
# 501774360    6
# Name: count, dtype: int64
#
#
#
# 186     9799732
# 187     9840073
# 188    10183052
# 189     9735693
# 191     9869139
# 192     9976012
# Name: ID, dtype: object

# %%
# Ordenar nova dataframe por ordem decrescente de ocorrência do NIF2 ( nif da entidade adjudicatária ) 
ordem1 = novadf['NIF2'].value_counts().index
novadf_1 = novadf.sort_values(by='NIF2', key=lambda x: pd.Categorical(x, categories = ordem1), ignore_index=True)

# %%
for i in novadf_1.NIF2.value_counts().index:

    cont = novadf_1.loc[novadf_1['NIF2'] == i,'NIF1'].value_counts()

    if len(cont[cont > 5].values):
        print('NIF2 =',i)
        print(cont[cont > 5])
        print('\n\n')
        
    cont = 0
# Out:
# NIF2 = 504272179
# NIF1
# 509540716    39
# Name: count, dtype: int64
#
#
#
# NIF2 = 515777048
# NIF1
# 509540716    31
# Name: count, dtype: int64
#
#
#
# NIF2 = 501774360
# NIF1
# 509540716    16
# 510928374     6
# Name: count, dtype: int64
#
#
#
# NIF2 = 506360237
# NIF1
# 509540716    9
# Name: count, dtype: int64
#
#
#
# NIF2 = 515371378
# NIF1
# 509540716    18
# Name: count, dtype: int64
#
#
#
# NIF2 = 502726890
# NIF1
# 504322915    6
# Name: count, dtype: int64
#
#
#
# NIF2 = 503222364
# NIF1
# 509540716    8
# Name: count, dtype: int64
#
#
#
# NIF2 = 510098711
# NIF1
# 509540716    6
# Name: count, dtype: int64

# %% [markdown]
# # Caso 1

# %% [markdown]
# **1** : Determinal qual o NIF da entidade adjudicante com mais contratos celebrados no ano de 2023

# %%
# Lista de entidades adjudicantes com mais contratos celebrados no ano de 2023
cp[(cp['DataCel'].dt.year == 2023)].NIF1.value_counts()
# Out:
# NIF1
# 509540716    163
# 504322915     22
# 510928374     16
# 501442600     13
# 600084779     11
#             ...
# 600082628      1
# 680009671      1
# 507142217      1
# 515545180      1
# 600081028      1
# Name: count, Length: 228, dtype: int64

# %% [markdown]
# **2** : Determinar ID's de todos os contratos celebrados em 2023 pelo NIF = 509540716

# %%
ids2023 = cp[(cp['DataCel'].dt.year == 2023) & (cp['NIF1'] == '509540716')].ID

# %%
ids2023.values
# Out:
# array(['10332117', '10281794', '10281057', '10312468', '10312461',
#        '10312460', '10312472', '10335594', '10335548', '10311506',
#        '10338678', '10338639', '10337509', '10337405', '10337328',
#        '10337213', '10223856', '10230212', '10339729', '10339365',
#        '10338995', '10338918', '10261946', '10261915', '10170971',
#        '10170890', '10170852', '10170815', '10170466', '10170419',
#        '10188351', '10188319', '10188301', '10188270', '10204545',
#        '10204451', '10204302', '10204260', '10204230', '10203906',
#        '10203896', '10203881', '10207089', '10206843', '10103445',
#        '10103418', '10103391', '10103347', '10103327', '10103294',
#        '10106141', '10106119', '10113284', '10113260', '10113220',
#        '10113116', '10112952', '10162178', '10162119', '10161854',
#        '10161771', '10161710', '10161511', '10161447', '10161129',
#        '10168812', '10168757', '10168662', '10059221', '10059157',
#        '10059125', '10059100', '10059063', '10059039', '10058804',
#        '10058837', '10070491', '10080885', '10096038', '10095989',
#        '10095824', '10095769', '10099869', '10099668', '10099601',
#        '10099495', '10102514', '10102322', '10101151', '10101118',
#        '10101077', '10101046', '10101016', '10100993', '10100959',
#        '10100889', '9960977', '9959212', '9963281', '9963255', '9962255',
#        '9974738', '9974557', '9974496', '9991342', '9991266', '9996682',
#        '9996671', '9996663', '9996648', '9995991', '9995931', '9995895',
#        '9997215', '10010576', '10010396', '10010325', '10009799',
#        '10035815', '10035794', '10035765', '10035600', '10035549',
#        '10035502', '10035372', '10035314', '9915245', '9915243',
#        '9915241', '9913588', '9913506', '9913455', '9912692', '9912634',
#        '9928759', '9934338', '9934317', '9830201', '9830082', '9830038',
#        '9796839', '9825462', '9824923', '9824832', '9705220', '10222767',
#        '10223896', '10223875', '10230635', '10230582', '10230556',
#        '10230493', '10230326', '10230288', '10230172', '10229934',
#        '10228788', '10265100', '10281825', '10281770', '10280375',
#        '10311809', '10371571'], dtype=object)

# %%
cp.loc[(cp['DataCel'].dt.year == 2023) & (cp['NIF1'] == '509540716'),'NIF2'].value_counts()
# Out:
# NIF2
# 504272179    39
# 515777048    31
# 515371378    18
# 501774360    16
# 506360237     9
# 503222364     8
# 510098711     6
# 504665901     3
# 504729624     3
# 514436298     3
# 507902238     3
# 502604751     3
# 503412031     2
# 516411810     2
# 507025229     2
# 504615947     2
# 504642251     1
# 514756969     1
# 502726890     1
# 502605731     1
# 504320882     1
# 509117660     1
# 508991579     1
# 502479418     1
# 502216336     1
# 516064932     1
# 501570691     1
# 507969332     1
# 504243926     1
# Name: count, dtype: int64

# %%
Xx = cp.loc[(cp['DataCel'].dt.year == 2023) & (cp['NIF1'] == '509540716'),'NIF2'].value_counts()

print('Número de contratos publicados :', Xx.sum())
# Out:
# Número de contratos publicados : 163

# %%
print('NIF2 \t\t NrContratos \t Rácio \t')

for i,j in enumerate(Xx):
    print(Xx.index[i], '\t',  Xx.values[i], '\t\t', np.round(Xx.values[i]/Xx.sum(),3)*100)
# Out:
# NIF2 		 NrContratos 	 Rácio
# 504272179 	 39 		 23.9
# 515777048 	 31 		 19.0
# 515371378 	 18 		 11.0
# 501774360 	 16 		 9.8
# 506360237 	 9 		 5.5
# 503222364 	 8 		 4.9
# 510098711 	 6 		 3.6999999999999997
# 504665901 	 3 		 1.7999999999999998
# 504729624 	 3 		 1.7999999999999998
# 514436298 	 3 		 1.7999999999999998
# 507902238 	 3 		 1.7999999999999998
# 502604751 	 3 		 1.7999999999999998
# 503412031 	 2 		 1.2
# 516411810 	 2 		 1.2
# 507025229 	 2 		 1.2
# 504615947 	 2 		 1.2
# 504642251 	 1 		 0.6
# 514756969 	 1 		 0.6
# 502726890 	 1 		 0.6
# 502605731 	 1 		 0.6
# 504320882 	 1 		 0.6
# 509117660 	 1 		 0.6
# 508991579 	 1 		 0.6
# 502479418 	 1 		 0.6
# 502216336 	 1 		 0.6
# 516064932 	 1 		 0.6
# 501570691 	 1 		 0.6
# 507969332 	 1 		 0.6
# 504243926 	 1 		 0.6

# %%
indices = ((cp.ID[(cp.DataCel.dt.year == 2023) & (cp.NIF1 == '509540716')])).index

print('ID \t\t NIF \t\t NrEntidadesConcorrentes  EntidadeVencedora \t RácioConcursosGanhos')

for i in (indices):
    #print(j, '\t', cp.NIF1[i], '\t\t', len(nec[i]) + 1, '\t\t')
    print(cp.ID[i], '\t', cp.NIF1[i], '\t', len(nr_entidades(cp.ID[i])), '\t\t\t', cp.NIF2[i], '\t\t\t', np.round(nr_contrato(cp,2023,cp.NIF2[i])/len(indices)*100,2))
# Out:
# ID 		 NIF 		 NrEntidadesConcorrentes  EntidadeVencedora 	 RácioConcursosGanhos

# %%
def nr_entidades(Id):
    """
    Função que, dado o id de um contrato, retorna uma lista com as entidades concorrentes. Desta forma, podemos calcular o número de entidades concorrentes utilizando o comando len()
    Se se der como input apenas um contrato - o id deste irá ter length = 8 visto que cada ID é composto por 8 algarismos - irá ser realizado no primeiro ramo do ciclo if-else
    Se se der um tuplo de ID's irá ser calculado no segundo ramo do ciclo e será retornada uma lista de listas

    Parâmetros:
        Id : id do contrato

    return:
        result : lista com a entidades concorrentes
    """

    if len(Id) == 8:
    
        cur = conn.cursor()
        cur.execute('''
                    SELECT entidades_concorrentes
                    FROM "contratos"
                    WHERE id = %s;''', (Id,))
        
        data = cur.fetchall()
        result = data[0][0].split('|||')
    
        return result

    
    else:
        
        cur = conn.cursor()
        cur.execute('''
                    SELECT entidades_concorrentes
                    FROM "contratos"
                    WHERE id IN %s; ''', (tuple(Id),))
            
        data = cur.fetchall()
        
        n = len(data)
        r = [] 
        result = []
        
        for i in range(n):
            r = data[i][0].split('|||')
            result.append(r)
            
        return result

# %%
nec = nr_entidades(cp.ID)
